# %% [markdown]
# # 19. Find the intersection of multiple lists.

# %%
l = [1,2,3,4,5]

i = [2,1,6,7,8]

s = [6,2,1,10,12]

set(l) & set(i) & set(s)
# Out:
# {1, 2}

# %% [markdown]
# # 20 Write a function that accepts any number of arguments and returns their average.

# %%
def avg(a,b,c,d,e):
    
    return (a + b + c + d + e )/ 5

avg(10,20,30,40,50)
# Out:
# 30.0
