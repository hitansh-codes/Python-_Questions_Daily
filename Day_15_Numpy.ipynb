# %%
import numpy as np 
import matplotlib.pyplot as plt

# %% [markdown]
# # 16. Create an array of 1000 random values and examine its distribution.

# %%
r = np.random.randint(1,1001,size = 1000)
r

distribution = plt.hist(r)
distribution 

plt.show()

# %% [markdown]
# # 17. Find the top 10 largest values in an array.

# %%
arr = np.array([1,6,7,8,10,15,16,44,55,88,10,99,100,34,58,0,1000])

np.sort(arr)[-10:]
# Out:
# array([  15,   16,   34,   44,   55,   58,   88,   99,  100, 1000])

# %%
>>> np.max([5], initial=6)
6
