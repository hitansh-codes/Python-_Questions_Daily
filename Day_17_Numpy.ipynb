# %%
import numpy as np 
import time
import sys

# %% [markdown]
# # 20. Compare the performance of Python lists vs NumPy arrays.

# %%
list_p = list(range(10000))


start = time.time()

result_list = [x * 2 for x in list_p]

list_time = time.time() - start

print("time :" , list_time , "Seconds")
print(sys.getsizeof(list_p),"Bytes")
# Out:
# time : 0.0011186599731445312 Seconds
# 80056 Bytes

# %%
arr = np.arange(10000)

start = time.time()

result_arr = arr * 2

numpy_time = time.time() - start


print(numpy_time , "Sec")
print(  arr.nbytes, "Bytes")
# Out:
# 9.775161743164062e-05 Sec
# 80000 Bytes
