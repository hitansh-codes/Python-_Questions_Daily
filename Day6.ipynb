# %% [markdown]
# # 15. Merge two dictionaries.

# %%
d1 = {"Name" : "Hitansh", "Age" : 22 , "Title" : "Villian"}

d2 = {"Name_" : "kurya", "Age_" : 26 , "Title_" : "Dummy"}

merge = d1 | d2

merge
# Out:
# {'Name': 'Hitansh',
#  'Age': 22,
#  'Title': 'Villian',
#  'Name_': 'kurya',
#  'Age_': 26,
#  'Title_': 'Dummy'}

# %% [markdown]
# # 16. Find dictionary keys having the maximum value.

# %%
d = {"v":5,"v1":20,"v3":50,"v4":40}

max_values= max(d.values())

max_values
# Out:
# 50
